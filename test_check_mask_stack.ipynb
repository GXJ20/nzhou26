# %%
import mrcfile
import matplotlib.pyplot as plt
with mrcfile.open('train_data/20s/mask_mrcs/14sep05c_c_00003gr_00014sq_00007hl_00004es_c.mrcs') as mrc:
    slice0 = mrc.data[0]
    slice1 = mrc.data[1]

# %%
plt.imshow(slice1)
